# %%
import pandas as pd

# %%
df = pd.read_csv("health-expenditure.csv")
df
# Out:
#     Unnamed: 0 GOVERNMENT HEALTH EXPENDITURE  \
# 0          NaN                           NaN
# 1          NaN                           NaN
# 2          NaN                           NaN
# 3          NaN                             ·
# 4          NaN                           NaN
# 5          NaN                             ·
# 6          NaN                           NaN
# 7          NaN                             ·
# 8          NaN                           NaN
# 9          NaN                             ·
# 10         NaN                           NaN
# 11         NaN                           NaN
# 12         NaN                           NaN
# 13         NaN                           NaN
# 14         NaN                        Notes:
# 15         NaN                             1
# 16         NaN                           NaN
#
#                                            Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# ...
