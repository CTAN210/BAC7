# %%
import pandas as pd
import seaborn as sb
import pylab as py
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import folium
from folium import plugins
from geopy.geocoders import Nominatim
import datetime
import statsmodels.api as sm

# %%
df = pd.read_csv('microplastics-in-ocean.csv')
df.head()
# Out:
#    Year  Accumulated ocean plastic: Microplastics (<0.5cm)  \
# 0  1950                                                  0
# 1  1951                                                  0
# 2  1952                                                  0
# 3  1953                                                  0
# 4  1954                                                100
#
#    Yearly Microplastics Emission
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                            100

# %%
df.describe()
# Out:
#               Year  Accumulated ocean plastic: Microplastics (<0.5cm)  \
# count   101.000000                                       1.010000e+02
# mean   2000.000000                                       5.180168e+05
# std      29.300171                                       7.085749e+05
# min    1950.000000                                       0.000000e+00
# 25%    1975.000000                                       1.080000e+04
# 50%    2000.000000                                       1.545000e+05
# 75%    2025.000000                                       7.873000e+05
# max    2050.000000                                       2.652700e+06
#
#        Yearly Microplastics Emission
# count                     101.000000
# mean                    26264.356436
# std                     31584.418893
# min                         0.000000
# 25%                      1500.000000
# 50%                     11600.000000
# 75%                     42100.000000
# ...

# %%
df.isnull().any()
# Out:
# Year                                                 False
# Accumulated ocean plastic: Microplastics (<0.5cm)    False
# Yearly Microplastics Emission                        False
# dtype: bool

# %%
df = df.loc[(df['Year'] >= 1973) & (df['Year'] <= 2000)]
df
# Out:
#     Year  Accumulated ocean plastic: Microplastics (<0.5cm)  \
# 23  1973                                               7900
# 24  1974                                               9300
# 25  1975                                              10800
# 26  1976                                              12600
# 27  1977                                              14600
# 28  1978                                              16800
# 29  1979                                              19300
# 30  1980                                              22000
# 31  1981                                              25000
# 32  1982                                              28200
# 33  1983                                              31700
# 34  1984                                              35600
# 35  1985                                              39700
# 36  1986                                              44200
# 37  1987                                              49100
# ...

# %%
df_cancer = pd.read_csv('all-cancer-data.csv')
df_cancer.head()
# Out:
#               Label    1983    1984    1985    1986    1987    1988    1989  \
# 0  Cancer incidence  148702  152774  156673  159724  167580  169120  172249
#
#      1990    1991  ...    2001    2002    2003    2004    2005    2006  \
# 0  176851  182142  ...  223136  227444  228575  234043  238162  241523
#
#      2007    2008    2009    2010
# 0  247237  255002  260593  264168
#
# [1 rows x 29 columns]

# %%
df_cancer = df_cancer.T
df_cancer.columns = df_cancer.iloc[0]
df_cancer = df_cancer.drop("Label")
df_cancer.head()
# Out:
# Label Cancer incidence
# 1983            148702
# 1984            152774
# 1985            156673
# 1986            159724
# 1987            167580

# %%
len(df_cancer)
# Out:
# 28

# %%
X = df['Yearly Microplastics Emission']
X = X.reset_index().drop(columns = "index")

y = df_cancer['Cancer incidence']
y = y.reset_index().drop(columns = "index")
