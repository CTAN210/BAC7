# %%
import pandas as pd
import seaborn as sb
import pylab as py
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import folium
from folium import plugins
from geopy.geocoders import Nominatim
import datetime
import statsmodels.api as sm

# %%
df = pd.read_csv('microplastics-in-ocean.csv')
df.head()
# Out:
#    Year  Accumulated ocean plastic: Microplastics (<0.5cm)  \
# 0  1950                                                  0
# 1  1951                                                  0
# 2  1952                                                  0
# 3  1953                                                  0
# 4  1954                                                100
#
#    Yearly Microplastics Emission
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                            100

# %%
df.describe()
# Out:
#               Year  Accumulated ocean plastic: Microplastics (<0.5cm)  \
# count   101.000000                                       1.010000e+02
# mean   2000.000000                                       5.180168e+05
# std      29.300171                                       7.085749e+05
# min    1950.000000                                       0.000000e+00
# 25%    1975.000000                                       1.080000e+04
# 50%    2000.000000                                       1.545000e+05
# 75%    2025.000000                                       7.873000e+05
# max    2050.000000                                       2.652700e+06
#
#        Yearly Microplastics Emission
# count                     101.000000
# mean                    26264.356436
# std                     31584.418893
# min                         0.000000
# 25%                      1500.000000
# 50%                     11600.000000
# 75%                     42100.000000
# max                    114700.000000

# %%
df.isnull().any()
# Out:
# Year                                                 False
# Accumulated ocean plastic: Microplastics (<0.5cm)    False
# Yearly Microplastics Emission                        False
# dtype: bool

# %%
df = df.loc[(df['Year'] >= 1975) & (df['Year'] <= 2000)]
df.insert(0, 'Time', range(1, 1 + len(df)))
df = df.drop(["Accumulated ocean plastic: Microplastics (<0.5cm)"], axis = 1)
df.head()
# Out:
#     Time  Year  Yearly Microplastics Emission
# 25     1  1975                           1500
# 26     2  1976                           1800
# 27     3  1977                           2000
# 28     4  1978                           2200
# 29     5  1979                           2500

# %%
df_cancer = pd.read_csv('cancer.csv')
df_cancer.head()
# Out:
#    Year  Bulgaria  Belarus  Canada  Chile  China  Colombia  Costa Rica  \
# 0  1978         0     7364       0      0      0         0           0
# 1  1979         0     7650       0      0      0         0           0
# 2  1980         0     7933       0      0      0         0           0
# 3  1981         0     8368       0      0      0         0           0
# 4  1982         0     8792       0      0      0         0        1349
#
#    Croatia  Czechia  ...  Spain  Sweden  Switzerland  Brazil  Thailand  \
# 0        0        0  ...      0   15951            0       0         0
# 1        0        0  ...      0   16301            0       0         0
# 2        0        0  ...      0   16815            0       0         0
# 3        0        0  ...      0   16843            0       0         0
# 4        0        0  ...      0   17400            0       0         0
#
#    Turkey  Uganda  Ukraine     UK     USA
# 0       0       0        0  80691   93651
# 1       0       0        0  83088   95971
# 2       0       0        0  85412   98693
# 3       0       0        0  87263  102263
# 4       0       0        0  87862  104376
#
# [5 rows x 43 columns]

# %%
df_cancer = df

# %%
X = df
# X = X.reset_index().drop(columns = ["index","Year"])
X = X.reset_index().drop(columns = ["index","Year","Time"])

y = df_cancer['Cancer incidence']
y = y.reset_index().drop(columns = "index")
y = y.astype(float)

# Define the modell
X = sm.add_constant(X)
model = sm.OLS(y, X)

# Fit the model
model_fit = model.fit()

# Print the model summary
print(model_fit.summary())
# print(model_fit.rsquared)
# print(model_fit.rsquared_adj)
# print(model_fit.pvalues)
# print(model_fit.params)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cancer incidence'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/04/7d_q61995kb_fww813kkkh9r0000gn/T/ipykernel_8136/4069611590.py in <module>
#       3 X = X.reset_index().drop(columns = ["index","Year","Time"])
#       4
# ----> 5 y = df_cancer['Cancer incidence']
#       6 y = y.reset_index().drop(columns = "index")
#       7 y = y.astype(float)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Cancer incidence'

# %%
sb.regplot(x=X["Yearly Microplastics Emission"], y=y)

# %%
male_df = pd.read_csv('bmi/male-bmi.csv')
male_df = male_df.loc[(male_df['Year'] >= 1975) & (male_df['Year'] <= 2000)]
male_df = male_df.groupby(['Year']).median()
male_df.head()

# %%
female_df = pd.read_csv('bmi/female-bmi.csv')
female_df = female_df.loc[(female_df['Year'] >= 1975) & (female_df['Year'] <= 2000)]
female_df = female_df.groupby(['Year']).median()
female_df.head()

# %%
gender_df = pd.read_excel('bmi/gender-ratio.xlsx')
gender_df["Male_Per"] = gender_df["Male"]/(gender_df["Male"] + gender_df["Female"])
gender_df["Female_Per"] = 1 - gender_df["Male_Per"]
gender_df = gender_df.loc[(gender_df['Year'] >= 1975) & (gender_df['Year'] <= 2000)]
gender_df.head()

# %%
male_df = male_df.reset_index()
female_df = female_df.reset_index()
gender_df = gender_df.reset_index()

# %%
bmi_df = pd.DataFrame()
bmi_df["Year"] = gender_df["Year"]
bmi_df["BMI"] = male_df["Mean BMI (male)"]*gender_df["Male_Per"] + female_df["Mean BMI (female)"]*gender_df["Female_Per"]

bmi_df.head()

# %%
X = df
# X = X.reset_index().drop(columns = ["index","Year"])
X = X.reset_index().drop(columns = ["index","Year","Time"])

y = df_cancer['Cancer incidence']
y = y.reset_index().drop(columns = "index")
y = y.astype(float)

# Define the modell
X = sm.add_constant(X)
model = sm.OLS(y, X)

# Fit the model
model_fit = model.fit()

# Print the model summary
print(model_fit.summary())

# %%
X = df
# X = X.reset_index().drop(columns = ["index","Year"])
X = X.reset_index().drop(columns = ["index","Year","Time"])

# bmi df refactoring
bmi_df = bmi_df.drop(columns = "Year")
bmi_df = bmi_df.reset_index()

X = pd.concat([X, bmi_df], axis = 1)
X = X.drop(columns = ["index"])

y = df_cancer['Cancer incidence']
y = y.reset_index().drop(columns = "index")
y = y.astype(float)

# Define the modell
X = sm.add_constant(X)
model = sm.OLS(y, X)

# Fit the model
model_fit = model.fit()

# Print the model summary
print(model_fit.summary())
